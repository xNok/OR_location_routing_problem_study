# %%
import csv
import math as m
from random import uniform as unif
import networkx as nx
import pandas as pd
import os

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
expid = "./exp1_run2"

# %%
if not os.path.exists(expid):
    os.makedirs(expid)

# %% [markdown]
# # Problem instance

# %% [markdown]
# ## Geographic data

# %%
from pkg.read_problem import read_problem, extract_problem

# %%
xy_customers, xy_icps, xy_crcs, xy_pc, q = read_problem('./datasets/original')

# %%
# xy_icps = xy_icps + [[unif(20,100),unif(20,70)] for i in range(10)]
# xy_crcs = xy_crcs + [[unif(20,100),unif(20,70)] for i in range(5)]

# %%
I,J,C,B,K,V,W,DcUj,Dcj,Dc,FCV,FCT,FCR,U = extract_problem(xy_customers, xy_icps, xy_crcs, xy_pc, q)

# %% [markdown]
# ## Capacity constraints

# %%
Q = [200 for j in range(J)]
V = [[200 for j in range(J)],[800 for c in range(C)]]

# %% [markdown]
# ## Adapting costs

# %%
# two-level cost
FCRD = []
for c in range(C):
    FCRD.append(FCR[c] + Dc[c])

f = FCT+FCRD
c = [[[W[i][j1] + Dcj[j1][j2] for j2 in range(C)] for j1 in range(J)] for i in range(I)]

# %% [markdown]
# # Plot Problem

# %%
from pkg.lrp_nodes_graph import lrp_nodes_graph, lrp_draw_and_save
G, pos, labels, colors, size = lrp_nodes_graph(xy_customers, xy_icps, xy_crcs, xy_pc)

lrp_draw_and_save(G, pos, labels, colors, size, expid+"/problem.png")

# %% [markdown]
# # Define Functions

# %% [markdown]
# ## run_uflp_cplex

# %%
def run_uflp_cplex(G,I,J,W,FCT,expid):
    from pkg.uflp_cplex import uflp_cplex

    prob, Y, N_icp = uflp_cplex(I,J,
                W,FCT,
                relaxation=False,path=expid+"/uflp_cplex.lp")

    G2 = G.copy()

    for j,vj in enumerate(Y):
        for i,vi in enumerate(vj):
            if vi == 1:
                G2.add_edge(I+i,j)

    lrp_draw_and_save(G2, pos, labels, colors, size, expid+"/uflp_cplex.png")

# %% [markdown]
# ## run_cflp_cplex

# %%
def run_cflp_cplex(G,I,J,W,FCT,U,Q,expid):
    from pkg.cflp_cplex import cflp_cplex

    prob, Y, N_icp = cflp_cplex(I,J,
                W,FCT,U,Q,
                relaxation=False,path=expid+"/cflp_cplex.lp")

    G2 = G.copy()

    for j,vj in enumerate(Y):
        for i,vi in enumerate(vj):
            if vi == 1:
                G2.add_edge(I+i,j)

    lrp_draw_and_save(G2, pos, labels, colors, size, expid+"/cflp_cplex.png")

# %% [markdown]
# ## run_tuflp_cplex

# %%
def run_tuflp_cplex(G,I,J,C,c,f,expid):
    from pkg.tuflp_cplex import tuflp_cplex

    prob, X, Z = tuflp_cplex(I,J,C,c,f,
                relaxation=False,path=expid+"/tcflp_cplex.lp")


    G2 = G.copy()

    for i in range(I):
        for j1 in range(J):
            for j2 in range(C):
                if X[i][j1][j2] == 1:
                    G2.add_edge(i,I+j1)

    lrp_draw_and_save(G2, pos, labels, colors, size, expid+"/tcflp_cplex.png")

# %% [markdown]
# ## run_tecflp_cplex

# %%
def run_tecflp_cplex(G,I,J,C,c,f,q,V,expid):
    from pkg.tecflp_cplex import tecflp_cplex

    prob, X, Z = tecflp_cplex(I,J,C,c,f,q,V,
                relaxation=False,path=expid+"/tecflp_cplex.lp")

    G2 = G.copy()

    for i in range(I):
        for j1 in range(J):
            for j2 in range(C):
                if X[i][j1][j2] == 1:
                    G2.add_edge(i,I+j1)

    lrp_draw_and_save(G2, pos, labels, colors, size, expid+"/tecflp_cplex.png")

# %% [markdown]
# ## run_crab_mb_m_cplex

# %%
def run_crab_mb_m_cplex(I,J,C,B,K,V,
            w,Dcj,FCV,FCT,FCR,Dc,q,
            Q, expid):
    from pkg.crab_mb_m_cplex import crab_mb_m_cplex

    prob, Y, Z, N, V = crab_mb_m_cplex(I,J,C,B,K,V,
            w,Dcj,FCV,FCT,FCR,Dc,q,
            Q, relaxation=False,path=expid+"/crab_mb_m_cplex.lp")
    
    print(prob.solution.get_objective_value())

    G2 = G.copy()

    for i in range(I):
        for j in range(J):
                if Y[i][j] == 1:
                    G2.add_edge(i,I+j)

    lrp_draw_and_save(G2, pos, labels, colors, size, expid+"/crab_mb_m_cplex.png")
    
    return prob, Y, Z, N, V

# %% [markdown]
# # Run experiment

# %%
result1 = %timeit -o run_uflp_cplex(G,I,J,W,FCT,expid)
# Out:
# The slowest run took 4.23 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1 loop, best of 3: 313 ms per loop

# %%
result2 = %timeit -o run_cflp_cplex(G,I,J,W,FCT,U,Q,expid)
# Out:
# 1 loop, best of 3: 606 ms per loop

# %%
result3 = %timeit -o run_tuflp_cplex(G,I,J,C,c,f,expid)
# Out:
# 1 loop, best of 3: 436 ms per loop

# %%
result4 = %timeit -o run_tecflp_cplex(G,I,J,C,c,f,U,V,expid)
# Out:
# 1 loop, best of 3: 703 ms per loop

# %%
sprob, sY, sZ, sN, sV = run_crab_mb_m_cplex(I,J,C,B,K,V,W,DcUj,FCV,FCT,FCR,Dc,U,V,expid)
# Out:
# Default row names c1, c2 ... being created.
# 187 187 187
# Tried aggregator 1 time.
# MIP Presolve eliminated 9 rows and 34 columns.
# MIP Presolve modified 8 coefficients.
# Reduced MIP has 178 rows, 594 columns, and 1700 nonzeros.
# Reduced MIP has 584 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.03 sec. (1.07 ticks)
# Probing time = 0.00 sec. (1.09 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 178 rows, 594 columns, and 1700 nonzeros.
# Reduced MIP has 584 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.86 ticks)
# Probing time = 0.00 sec. (1.09 ticks)
# Clique table members: 1262.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.00 sec. (1.05 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0     3511.3782    20                   3511.3782      136
#       0     0     3532.1248    49                    Cuts: 74      192
#       0     0     3546.5015    65                    Cuts: 41      240
#       0     0     3551.7511    72                    Cuts: 25      276
#       0     0     3554.2284    77                    Cuts: 24      317
#       0     0     3556.0364    90                    Cuts: 27      338
#       0     0     3557.6851    73                    Cuts: 13      379
#       0     0     3558.8776   100                    Cuts: 33      412
#       0     0     3559.6616    47                    Cuts: 12      435
#       0     0     3559.7313    95                    Cuts: 20      447
#       0     0     3561.4407    87                     Cuts: 9      470
#       0     0     3561.4846    90                    Cuts: 28      482
#       0     2     3561.4846    90                   3563.6317      482
# Elapsed time = 1.15 sec. (85.58 ticks, tree = 0.01 MB, solutions = 0)
#    3777  2614     3866.3314    18                   3884.8315    27844
#   10181  4543     3982.5666    11                   3884.8315    60305
#   16982  8990     3965.2651    11                   3884.8315    91545
#   18713 11162     3843.0540    15                   3900.4697   107330
#   26806  4962     4003.0895    12                   3900.4697   139022
#   38229 11794     4209.8438     6                   3900.4697   183065
#   49455 18286     4221.3825     6                   3904.0638   226172
#   60463 24986     4102.0095     5                   3911.0109   274329
#   71654 30342     4070.2481     8                   3918.8242   313674
#  115357 54623     4153.8329    10                   3951.8554   505436
# Elapsed time = 21.28 sec. (5963.26 ticks, tree = 23.59 MB, solutions = 0)
#  158484 73744     4082.6048     9                   3998.9289   706714
#  200214 81011    infeasible                         4066.1241   905419
#  239379 80449     4200.2495     7                   4116.4716  1129606
#  277308 78342     4422.1473     9                   4155.7089  1338497
#  314493 80642     4321.7045    17                   4181.8506  1552132
#  355112 80862     4285.8102     4                   4203.8852  1755401
#  392759 79770     4267.2073    12                   4228.1824  1965528
#  429884 76611    infeasible                         4251.4169  2141271
#  467875 70845    infeasible                         4271.2053  2323273
#  502547 61929    infeasible                         4289.0143  2513192
# Elapsed time = 54.68 sec. (15500.23 ticks, tree = 28.13 MB, solutions = 0)
#  539883 52174     4517.7973     7                   4309.9300  2696338
#  574354 40248     4595.9372     8                   4341.1072  2861489
#  608367 23056     4654.9233     8                   4448.6903  3033155
#  639891  6657    infeasible                         4604.3635  3176877
#
# Root node processing (before b&c):
#   Real time             =    1.17 sec. (85.39 ticks)
# Parallel b&c, 8 threads:
#   Real time             =   69.00 sec. (19441.79 ticks)
#   Sync time (average)   =    5.26 sec.
#   Wait time (average)   =    0.33 sec.
#                           ------------
# Total (root+branch&cut) =   70.17 sec. (19527.18 ticks)
# CPLEX Error  1217: No solution exists.
# ---------------------------------------------------------------------------
# CplexSolverError                          Traceback (most recent call last)
# <ipython-input-22-ed0d77da7fc9> in <module>()
# ----> 1 sprob, sY, sZ, sN, sV = run_crab_mb_m_cplex(I,J,C,B,K,V,W,DcUj,FCV,FCT,FCR,Dc,U,V,expid)
#
# <ipython-input-15-842ea092a3bf> in run_crab_mb_m_cplex(I, J, C, B, K, V, w, Dcj, FCV, FCT, FCR, Dc, q, Q, expid)
#       6     prob, Y, Z, N, V = crab_mb_m_cplex(I,J,C,B,K,V,
#       7             w,Dcj,FCV,FCT,FCR,Dc,q,
# ----> 8             Q, relaxation=False,path=expid+"/crab_mb_m_cplex.lp")
#       9
#      10     print(prob.solution.get_objective_value())
#
# C:\Users\alexandre\Documents\Jupyter Workspace\P1_location_routing_problem\pkg\crab_mb_m_cplex.py in crab_mb_m_cplex(I, J, C, B, K, V, w, Dcj, FCV, FCT, FCR, Dc, q, Q, relaxation, path)
#     202     CuJ = len(C)+len(J); I = len(I); J = len(J); B = len(B); C = len(C);
#     203
# --> 204     solution = prob.solution.get_values()
#     205     Y = np.reshape(solution[0:I*J],(I,J))
#     206     Z = np.reshape(solution[I*J:I*J+CuJ*CuJ*B],(CuJ,CuJ,B))
#
# C:\ProgramData\Anaconda3\envs\py35\lib\site-packages\cplex\_internal\_subinterfaces.py in get_values(self, *args)
#    7566             return CPX_PROC.getx(self._env._e, self._cplex._lp, a, b)
#    7567         return apply_freeform_two_args(
# -> 7568             getx, self._cplex.variables.get_indices, args)
#    7569
#    7570     def get_reduced_costs(self, *args):
#
# C:\ProgramData\Anaconda3\envs\py35\lib\site-packages\cplex\_internal\_aux_functions.py in apply_freeform_two_args(fn, convert, args)
#      71             raise TypeError("expecting name or index")
#      72     elif len(args) == 0:
# ---> 73         return fn(0)
#      74     else:
#      75         raise WrongNumberOfArgumentsError()
#
# C:\ProgramData\Anaconda3\envs\py35\lib\site-packages\cplex\_internal\_subinterfaces.py in getx(a, b)
#    7564         """
#    7565         def getx(a, b = self._cplex.variables.get_num() - 1):
# -> 7566             return CPX_PROC.getx(self._env._e, self._cplex._lp, a, b)
#    7567         return apply_freeform_two_args(
#    7568             getx, self._cplex.variables.get_indices, args)
#
# C:\ProgramData\Anaconda3\envs\py35\lib\site-packages\cplex\_internal\_procedural.py in getx(env, lp, begin, end)
#    1510     x    = _safeDoubleArray(xlen)
#    1511     status = CR.CPXXgetx(env, lp, x, begin, end)
# -> 1512     check_status(env, status)
#    1513     return LAU.array_to_list(x, xlen)
#    1514
#
# C:\ProgramData\Anaconda3\envs\py35\lib\site-packages\cplex\_internal\_procedural.py in __call__(self, env, status, from_cb)
#     222                 else:
#     223                     error_string = geterrorstring(env, status)
# --> 224             raise CplexSolverError(error_string, env, status)
#     225
#     226 check_status = StatusChecker()
#
# CplexSolverError: CPLEX Error  1217: No solution exists.

# %%
["Z_" + str(c) + "_" + str(j) + "_" + str(b) for c in range(C+J) for j in range(J) for b in range(B) if sZ[c][j][b] >= 1]

# %%
print(sV,sN)

# %%
FCT

# %% [markdown]
# ## Results

# %%
objects = ('UFLP', 'CFLP', 'TUFLP', 'TCFLP')
y_pos = np.arange(len(objects))
performance = [result1.best,result2.best,result3.best,result4.best]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Time s')
plt.title('Best processing time for each subproblem')
 
plt.show()
