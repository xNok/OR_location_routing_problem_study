# %%
import csv
import math as m
from random import uniform as unif
import networkx as nx

import os

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
expid = "./exp1_run1"

# %%
if not os.path.exists(expid):
    os.makedirs(expid)

# %% [markdown]
# # Problem instance

# %% [markdown]
# ## Raw data

# %%
# locations
xy_customers = list(csv.reader(
    open('./datasets/original/xy_customers.csv'),delimiter=';',
    quoting=csv.QUOTE_NONNUMERIC))

xy_icps = list(csv.reader(
    open('./datasets/original/xy_icps.csv'),delimiter=';',
    quoting=csv.QUOTE_NONNUMERIC))

xy_crcs = list(csv.reader(
    open('./datasets/original/xy_crcs.csv'),delimiter=';',
    quoting=csv.QUOTE_NONNUMERIC))

xy_pc = [10.0,60.0]

# product return
Uq = list(csv.reader(
    open('./datasets/original/U.csv'),delimiter=' ',
    quoting=csv.QUOTE_NONNUMERIC))

# %%
xy_icps = xy_icps + [[unif(20,100),unif(20,70)] for i in range(10)]
xy_crcs = xy_crcs + [[unif(20,100),unif(20,70)] for i in range(5)]

# %% [markdown]
# ## Data pre-processing

# %%
# index
I = len(xy_customers)
J = len(xy_icps)
C = len(xy_crcs)

# %%
# distance cost
W = [[m.sqrt((cus[0]-icp[0])**2 + (cus[1]-icp[1])**2) for icp in xy_icps] for cus in xy_customers]
D = [[m.sqrt((icp[0]-crc[0])**2 + (icp[1]-crc[1])**2) for crc in xy_crcs] for icp in xy_icps ]
L = [m.sqrt((xy_pc[0]-crc[0])**2 + (xy_pc[1]-crc[1])**2) for crc in xy_crcs]

# %%
DL = [[D[j][c]+L[c] for c in range(C)] for j in range(J)]

# %%
# fixed setup cost
FCT = [100 for i in range(J)]
FCR = [200 for i in range(C)]

# %%
# Demand and capacity
U = []
for i in range(I):
    U.append(Uq[0][i] + Uq[1][i] + Uq[2][i])
    
Q = [200 for j in range(J)]
V = [[200 for j in range(J)],[800 for c in range(C)]]

# %%
# two-level cost
c = [[[W[i][j1] + DL[j1][j2] for j2 in range(C)] for j1 in range(J)] for i in range(I)]
f = FCT+FCR

# %% [markdown]
# # Plot Problem

# %%
from pkg.lrp_nodes_graph import lrp_nodes_graph, lrp_draw_and_save
G, pos, labels, colors, size = lrp_nodes_graph(xy_customers, xy_icps, xy_crcs, xy_pc)

lrp_draw_and_save(G, pos, labels, colors, size, expid+"/problem.png")

# %% [markdown]
# # Define Functions

# %% [markdown]
# ## run_uflp_cplex

# %%
def run_uflp_cplex(G,I,J,W,FCT,expid):
    from pkg.uflp_cplex import uflp_cplex

    prob, Y, N_icp = uflp_cplex(I,J,
                W,FCT,
                relaxation=False,path=expid+"/uflp_cplex.lp")

    G2 = G.copy()

    for j,vj in enumerate(Y):
        for i,vi in enumerate(vj):
            if vi == 1:
                G2.add_edge(I+i,j)

    plt.grid('on')
    nx.draw_networkx(G2,pos,labels=labels,node_color=colors,with_labels=True, node_size=size)
    plt.savefig(expid+"/uflp_cplex.png", format="PNG")

# %% [markdown]
# ## run_cflp_cplex

# %%
def run_cflp_cplex(G,I,J,W,FCT,U,Q,expid):
    from pkg.cflp_cplex import cflp_cplex

    prob, Y, N_icp = cflp_cplex(I,J,
                W,FCT,U,Q,
                relaxation=False,path=expid+"/cflp_cplex.lp")

    G2 = G.copy()

    for j,vj in enumerate(Y):
        for i,vi in enumerate(vj):
            if vi == 1:
                G2.add_edge(I+i,j)

    plt.grid('on')
    nx.draw_networkx(G2,pos,labels=labels,node_color=colors,with_labels=True, node_size=size)
    plt.savefig(expid+"/cflp_cplex.png", format="PNG")

# %% [markdown]
# ## run_tuflp_cplex

# %%
def run_tuflp_cplex(G,I,J,C,c,f,expid):
    from pkg.tuflp_cplex import tuflp_cplex

    prob, X, Z = tuflp_cplex(I,J,C,c,f,
                relaxation=False,path=expid+"/tcflp_cplex.lp")


    G2 = G.copy()

    for i in range(I):
        for j1 in range(J):
            for j2 in range(C):
                if X[i][j1][j2] == 1:
                    G2.add_edge(i,I+j1)

    plt.grid('on')
    nx.draw_networkx(G2,pos,labels=labels,node_color=colors,with_labels=True, node_size=size)
    plt.savefig(expid+"/tcflp_cplex.png", format="PNG")

# %% [markdown]
# ## run_tecflp_cplex

# %%
def run_tecflp_cplex(G,I,J,C,c,f,q,V,expid):
    from pkg.tecflp_cplex import tecflp_cplex

    prob, X, Z = tecflp_cplex(I,J,C,c,f,q,V,
                relaxation=False,path=expid+"/tecflp_cplex.lp")

    G2 = G.copy()

    for i in range(I):
        for j1 in range(J):
            for j2 in range(C):
                if X[i][j1][j2] == 1:
                    G2.add_edge(i,I+j1)

    plt.grid('on')
    nx.draw_networkx(G2,pos,labels=labels,node_color=colors,with_labels=True, node_size=size)
    plt.savefig(expid+"/tecflp_cplex.png", format="PNG")

# %% [markdown]
# # Run experiment

# %%
run_uflp_cplex(G,I,J,W,FCT,expid)
# Out:
# Default row names c1, c2 ... being created.
# Found incumbent of value 1989.529822 after 0.00 sec. (0.09 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 950 rows, 918 columns, and 2700 nonzeros.
# Reduced MIP has 918 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (2.59 ticks)
# Probing time = 0.00 sec. (0.90 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 950 rows, 918 columns, and 2700 nonzeros.
# Reduced MIP has 918 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.05 sec. (2.57 ticks)
# Probing time = 0.02 sec. (0.90 ticks)
# Clique table members: 950.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (1.82 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         1989.5298        0.0000           100.00%
# *     0+    0                         1483.5122        0.0000           100.00%
# *     0+    0                         1158.9776        0.0000           100.00%
# *     0     0      integral     0     1104.4809     1104.4809      253    0.00%
# Elapsed time = 0.34 sec. (10.81 ticks, tree = 0.00 MB, solutions = 4)
#
# Root node processing (before b&c):
#   Real time             =    0.34 sec. (10.86 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.34 sec. (10.86 ticks)

# %%
run_cflp_cplex(G,I,J,W,FCT,U,Q,expid)
# Out:
# Default row names c1, c2 ... being created.
# Tried aggregator 1 time.
# MIP Presolve eliminated 32 rows and 576 columns.
# MIP Presolve modified 18 coefficients.
# Reduced MIP has 36 rows, 342 columns, and 666 nonzeros.
# Reduced MIP has 342 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (1.02 ticks)
# Found incumbent of value 2701.541382 after 0.03 sec. (2.02 ticks)
# Probing time = 0.02 sec. (0.47 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 36 rows, 342 columns, and 666 nonzeros.
# Reduced MIP has 342 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (0.58 ticks)
# Probing time = 0.00 sec. (0.47 ticks)
# Clique table members: 342.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.00 sec. (0.22 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         2701.5414      237.4125            91.21%
# *     0+    0                          841.1752      237.4125            71.78%
# *     0+    0                          760.4352      237.4125            68.78%
# *     0+    0                          711.1458      237.4125            66.62%
#       0     0      609.3416     6      711.1458      609.3416       38   14.32%
#       0     0      650.2652     2      711.1458      Cuts: 29       64    8.56%
#       0     0      653.7273    30      711.1458       Cuts: 4       70    8.07%
#
# Repeating presolve.
# Tried aggregator 1 time.
# MIP Presolve eliminated 8 rows and 160 columns.
# Reduced MIP has 28 rows, 182 columns, and 354 nonzeros.
# Reduced MIP has 182 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.30 ticks)
# Probing time = 0.00 sec. (0.17 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 28 rows, 182 columns, and 354 nonzeros.
# Reduced MIP has 182 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.25 ticks)
# Represolve time = 0.05 sec. (0.95 ticks)
# Probing time = 0.00 sec. (0.17 ticks)
# Clique table members: 190.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.00 sec. (0.51 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          711.1458      653.7273             8.07%
#       0     0      653.7273    30      711.1458      653.7273      156    8.07%
#       0     0      656.5914    15      711.1458      Cuts: 13      166    7.67%
#       0     0      658.2190    12      711.1458       Cuts: 4      178    7.44%
#       0     0      658.7845    42      711.1458       Cuts: 7      185    7.36%
#       0     0      659.5715    33      711.1458       Cuts: 8      197    7.25%
#       0     0      660.5097    46      711.1458      Cuts: 10      206    7.12%
#       0     0      661.8909    44      711.1458       Cuts: 5      215    6.93%
#       0     0      662.6838    54      711.1458       Cuts: 8      226    6.81%
#       0     0      663.7358    50      711.1458      Cuts: 12      236    6.67%
#       0     0      664.4114    50      711.1458       Cuts: 7      247    6.57%
#       0     0      664.8466    31      711.1458      Cuts: 16      254    6.51%
#       0     0      664.9215    51      711.1458       Cuts: 4      260    6.50%
#       0     0      665.8073    54      711.1458       Cuts: 7      271    6.38%
#       0     0      666.0943    61      711.1458       Cuts: 8      282    6.34%
#       0     0      666.6695    56      711.1458       Cuts: 9      298    6.25%
#       0     0      667.0945    54      711.1458       Cuts: 8      308    6.19%
#       0     0      667.2331    55      711.1458       Cuts: 3      315    6.17%
#       0     0      667.6018    59      711.1458       Cuts: 9      335    6.12%
#       0     0      667.7429    56      711.1458       Cuts: 5      340    6.10%
#       0     0      667.8603    59      711.1458       Cuts: 8      347    6.09%
#       0     0      668.1698    57      711.1458       Cuts: 6      364    6.04%
#       0     0      668.4763    43      711.1458      Cuts: 10      382    6.00%
#       0     0      668.6341    55      711.1458       Cuts: 5      394    5.98%
#       0     0      668.7416    64      711.1458      Cuts: 11      405    5.96%
#
# Clique cuts applied:  12
# Cover cuts applied:  11
# Flow cuts applied:  1
# Mixed integer rounding cuts applied:  9
# Zero-half cuts applied:  12
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    1.09 sec. (39.25 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    1.09 sec. (39.25 ticks)

# %%
run_tuflp_cplex(G,I,J,C,c,f,expid)
# Out:
# Default row names c1, c2 ... being created.
# Tried aggregator 1 time.
# Reduced MIP has 1300 rows, 6325 columns, and 20150 nonzeros.
# Reduced MIP has 6325 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.08 sec. (17.16 ticks)
# Found incumbent of value 2352.168005 after 0.11 sec. (20.34 ticks)
# Probing time = 0.09 sec. (4.19 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 1300 rows, 6325 columns, and 20150 nonzeros.
# Reduced MIP has 6325 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.09 sec. (17.11 ticks)
# Probing time = 0.09 sec. (4.19 ticks)
# Clique table members: 1300.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.08 sec. (9.82 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         2352.1680        0.0000           100.00%
# *     0     0      integral     0     1821.4553     1821.4553      397    0.00%
# Elapsed time = 0.66 sec. (63.53 ticks, tree = 0.00 MB, solutions = 2)
#
# Root node processing (before b&c):
#   Real time             =    0.69 sec. (63.77 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.69 sec. (63.77 ticks)

# %%
run_tecflp_cplex(G,I,J,C,c,f,U,V,expid)
# Out:
# Default row names c1, c2 ... being created.
# Tried aggregator 1 time.
# MIP Presolve modified 25 coefficients.
# Reduced MIP has 75 rows, 6325 columns, and 18925 nonzeros.
# Reduced MIP has 6325 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.03 sec. (8.22 ticks)
# Found incumbent of value 6431.930491 after 0.11 sec. (23.65 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 75 rows, 6325 columns, and 18925 nonzeros.
# Reduced MIP has 6325 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.05 sec. (7.95 ticks)
# Probing time = 0.08 sec. (3.57 ticks)
# Clique table members: 12650.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.03 sec. (6.71 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         6431.9305        0.0000           100.00%
# *     0+    0                         3680.3257        0.0000           100.00%
# *     0+    0                         3517.5103        0.0000           100.00%
# *     0+    0                         3124.6956        0.0000           100.00%
#       0     0     1970.4580    20     3124.6956     1970.4580      142   36.94%
#       0     0     2136.4006    95     3124.6956     Cuts: 118      259   31.63%
# *     0+    0                         2645.1648     2136.4006            19.23%
#       0     0     2225.6518   140     2645.1648      Cuts: 82      361   15.86%
#       0     0     2268.0391   163     2645.1648      Cuts: 78      486   14.26%
#       0     0     2294.1660   185     2645.1648      Cuts: 78      631   13.27%
# *     0+    0                         2428.4754     2294.1660             5.53%
#       0     0     2300.4368   180     2428.4754      Cuts: 60      725    5.27%
#       0     0     2303.0488   220     2428.4754      Cuts: 21      783    5.16%
#       0     0     2305.7988   215     2428.4754      Cuts: 21      846    5.05%
#       0     0     2306.4881   220     2428.4754      Cuts: 26      882    5.02%
# *     0+    0                         2355.4472     2306.4881             2.08%
#
# Repeating presolve.
# Tried aggregator 1 time.
# MIP Presolve eliminated 0 rows and 1589 columns.
# Reduced MIP has 75 rows, 4736 columns, and 14158 nonzeros.
# Reduced MIP has 4736 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (6.71 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 75 rows, 4736 columns, and 14158 nonzeros.
# Reduced MIP has 4736 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.03 sec. (6.08 ticks)
# Represolve time = 0.08 sec. (23.09 ticks)
# Probing time = 0.02 sec. (2.97 ticks)
# Clique table members: 9472.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.06 sec. (34.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         2355.4472     2306.4881             2.08%
#       0     0     2306.4881   220     2355.4472     2306.4881     1433    2.08%
#       0     0     2307.1955   220     2355.4472      Cuts: 24     1474    2.05%
#       0     0     2307.9410   226     2355.4472      Cuts: 17     1519    2.02%
#       0     0     2308.4638   230     2355.4472      Cuts: 23     1559    1.99%
#       0     0     2308.6326   220     2355.4472      Cuts: 17     1603    1.99%
#       0     0     2308.8563   240     2355.4472      Cuts: 19     1628    1.98%
#       0     0     2308.8911   228     2355.4472       Cuts: 8     1637    1.98%
#       0     0     2308.8999   249     2355.4472    MIRcuts: 4     1648    1.98%
# *     0+    0                         2350.4696     2308.8999             1.77%
#       0     2     2308.8999   249     2350.4696     2308.8999     1648    1.77%
# Elapsed time = 3.15 sec. (785.67 ticks, tree = 0.01 MB, solutions = 8)
#     428   292     2349.5868    17     2350.4696     2309.0043     8312    1.76%
#    1604  1072        cutoff           2350.4696     2310.4623    22214    1.70%
#    2820  1907     2350.1147     3     2350.4696     2316.1014    36998    1.46%
#    3430  2467     2309.1732   255     2350.4696     2317.0367    49096    1.42%
#    3450    96     2328.0811    31     2350.4696     2317.0367    49684    1.42%
#    3883   192     2338.2240     9     2350.4696     2317.0367    55148    1.42%
#    4743   567        cutoff           2350.4696     2317.0367    67950    1.42%
#    5923   548        cutoff           2350.4696     2339.1198    86538    0.48%
#
# GUB cover cuts applied:  28
# Clique cuts applied:  136
# Cover cuts applied:  103
# Flow cuts applied:  2
# Mixed integer rounding cuts applied:  46
# Zero-half cuts applied:  11
#
# Root node processing (before b&c):
#   Real time             =    3.13 sec. (784.81 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    5.40 sec. (2613.22 ticks)
#   Sync time (average)   =    1.03 sec.
#   Wait time (average)   =    0.04 sec.
#                           ------------
# Total (root+branch&cut) =    8.53 sec. (3398.03 ticks)
